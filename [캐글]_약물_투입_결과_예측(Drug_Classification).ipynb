# %% [markdown]
# <a href="https://colab.research.google.com/github/smpark0520/ESAA/blob/main/%5B%EC%BA%90%EA%B8%80%5D_%EC%95%BD%EB%AC%BC_%ED%88%AC%EC%9E%85_%EA%B2%B0%EA%B3%BC_%EC%98%88%EC%B8%A1(Drug_Classification).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# - 사용 모델(1개, Scikit-learn 사용)
#
# - 앙상블 [Random Forest Classification]
#
# 성능 평가 지표
#
# - Accuracy, precision, recall, f1-score, support
#
# 데이터셋 변수(6개)
#
# - Age(나이), sex(성별), BP(혈압 수준), Cholestrol(콜레스테롤 수준), Na_to_K(체내 나트륨과 칼륨 비율), Drug(약물 타입)
#
# 분류 타겟 값
#
# - Drug(약물 타입)
# [출처] [캐글] 머신러닝/분류 - 약물 투입 결과 예측(Drug Classification)

# %% [markdown]
# # 1. 라이브러리 import & 데이터 Load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_curve
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import  classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/drive/MyDrive/drug200.csv')
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %% [markdown]
# # 2. EDA (Exploratory Data Analysis)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
# 모든 변수 결측치 확인
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
# object 타입 value 개수
print(df['Sex'].value_counts())
print(df['BP'].value_counts())
print(df['Cholesterol'].value_counts())
# Out:
# Sex
# M    104
# F     96
# Name: count, dtype: int64
# BP
# HIGH      77
# LOW       64
# NORMAL    59
# Name: count, dtype: int64
# Cholesterol
# HIGH      103
# NORMAL     97
# Name: count, dtype: int64

# %%
# 분류 클래스(target) 'Drug' value 개수
df['Drug'].value_counts()
# Out:
# Drug
# DrugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: count, dtype: int64

# %%
# Pie Chart로 확인
plt.figure(figsize=(5, 5))
explode = [0.03, 0.03, 0.03, 0.03, 0.03]
colors = ['#A8D1E7', '#FCFAF2', '#FFBFC5', '#EB8DB5', '#D4A3C4']

plt.pie(df["Drug"].value_counts(), labels=df["Drug"].value_counts().index, autopct='%1.1f%%', startangle=90, explode=explode, colors=colors, shadow=True)
plt.title('Type of Drug')
plt.show()

# %%
# bar chart로 확인
palette1 = sns.color_palette('coolwarm', 5)
ax = sns.countplot(x=df['Drug'], palette=palette1)
plt.title('Type of Drug')

# countplot에 값 표시
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 3, round(height), ha = 'center', size = 12)
ax.set_ylim(0, 110)
plt.show()

# %%
# 데이터 전체 통계
df.describe()
# Out:
#               Age     Na_to_K
# count  200.000000  200.000000
# mean    44.315000   16.084485
# std     16.544315    7.223956
# min     15.000000    6.269000
# 25%     31.000000   10.445500
# 50%     45.000000   13.936500
# 75%     58.000000   19.380000
# max     74.000000   38.247000

# %% [markdown]
# # 3. 데이터 전처리

# %%
# 라벨인코딩 (object -> int형 변환)
cols = df.select_dtypes(include=object).columns
LabelEncoder = LabelEncoder()
for col in cols:
    df[col] = LabelEncoder.fit_transform(df[col])
df.head()
# Out:
#    Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0   23    0   0            0   25.355     0
# 1   47    1   1            0   13.093     3
# 2   47    1   1            0   10.114     3
# 3   28    0   2            0    7.798     4
# 4   61    0   1            0   18.043     0

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Age'}>, <Axes: title={'center': 'Sex'}>],
#        [<Axes: title={'center': 'BP'}>,
#         <Axes: title={'center': 'Cholesterol'}>],
#        [<Axes: title={'center': 'Na_to_K'}>,
#         <Axes: title={'center': 'Drug'}>]], dtype=object)

# %%
# 변수 간 상관관계 확인
df.corr()
# Out:
#                   Age       Sex        BP  Cholesterol   Na_to_K      Drug
# Age          1.000000  0.102027  0.054212    -0.068234 -0.063119  0.041856
# Sex          0.102027  1.000000 -0.007814    -0.008811 -0.125008  0.018239
# BP           0.054212 -0.007814  1.000000    -0.137552 -0.149312  0.419397
# Cholesterol -0.068234 -0.008811 -0.137552     1.000000  0.010000  0.048415
# Na_to_K     -0.063119 -0.125008 -0.149312     0.010000  1.000000 -0.689051
# Drug         0.041856  0.018239  0.419397     0.048415 -0.689051  1.000000

# %%
# Heatmap으로 상관관계 확인
sns.set_style('ticks')
plt.rcParams['figure.figsize'] = (5, 5)
sns.heatmap(df.corr(), annot=True, fmt='.3f', cmap='BuGn')
# Out:
# <Axes: >

# %% [markdown]
# # 4. 모델 학습 & 성능 평가

# %%
# 데이터 Train, Test 나누기
X_train, X_test, y_train, y_test = train_test_split(
    df.drop('Drug', axis=1), df['Drug'], test_size=0.3, random_state=1234
)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (140, 5) (60, 5) (140,) (60,)

# %%
X_train.head(3)
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K
# 97    56    0   0            0   25.395
# 66    29    1   0            0   12.856
# 122   34    1   2            0   22.456

# %%
y_train.head(3)
# Out:
# 97     0
# 66     1
# 122    0
# Name: Drug, dtype: int64

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 140 entries, 97 to 47
# Series name: Drug
# Non-Null Count  Dtype
# --------------  -----
# 140 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2 KB

# %%
# 모델 학습
model = RandomForestClassifier(random_state=1234, max_depth=4, n_estimators=800)
model.fit(X_train, y_train)
pred = model.predict(X_test)
pred_proba = model.predict_proba(X_test)

# %%
# AUC 면적 구하기
fpr, tpr, thresh = roc_curve(y_test, pred_proba[:,1], pos_label=1)
plt.style.use('default')
plt.plot(fpr, tpr, color='blue', label='RandomForestClassifier')
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('ROC',dpi=400)
plt.show()

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        27
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00         4
#            3       1.00      0.75      0.86         4
#            4       0.95      1.00      0.97        18
#
#     accuracy                           0.98        60
#    macro avg       0.99      0.95      0.97        60
# weighted avg       0.98      0.98      0.98        60

# %%
mask = np.zeros_like(confusion_matrix(y_test , pred))
mask[np.triu_indices_from(mask)] = True

# %%
sns.heatmap(confusion_matrix(y_test , pred), annot=True, cmap='PuBu', vmin=-1, vmax=3, cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# # 5. 잘못 분류된 케이스 확인

# %%
check = pd.DataFrame(
    {
        'y':y_test,
        'pred':pred
    }
)
check['result'] = check['pred'] == check['y']
dataFilter = check['result'] == False
ft_check = check[dataFilter]
ft_check
# Out:
#      y  pred  result
# 193  3     4   False

# %%
# Drug3 확인
drug3 = df['Drug'] == 3
drug3_df = df[drug3]
drug3_df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 1     47    1   1            0   13.093     3
# 2     47    1   1            0   10.114     3
# 7     41    1   1            0   11.037     3
# 10    47    0   1            0   11.767     3
# 18    23    1   1            0    7.298     3
# 47    68    1   1            0   10.291     3
# 55    26    0   1            0   14.160     3
# 82    32    0   1            0    9.712     3
# 84    47    0   1            0   10.067     3
# 102   28    0   1            0   13.127     3
# 149   22    1   1            0    8.151     3
# 155   49    1   1            0   10.537     3
# 158   59    0   1            0   10.444     3
# 193   72    1   1            0    6.769     3
# 195   56    0   1            0   11.567     3
# 196   16    1   1            0   12.006     3

# %%
# Drug4만 확인
drug4 = df['Drug'] == 4
drug4_df = df[drug4]
drug4_df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 3     28    0   2            0    7.798     4
# 5     22    0   2            0    8.607     4
# 14    50    0   2            0   12.703     4
# 16    69    1   1            1   11.455     4
# 27    49    0   2            1    9.381     4
# 30    18    0   2            1    8.750     4
# 32    49    1   1            1   11.014     4
# 34    53    1   2            0   14.133     4
# 35    46    1   2            1    7.285     4
# 37    39    1   1            1   13.938     4
# 38    39    0   2            1    9.709     4
# 39    15    1   2            0    9.084     4
# 43    23    1   2            0   12.260     4
# 44    50    0   2            1   12.295     4
# 45    66    0   2            1    8.107     4
# 51    67    1   2            1   10.898     4
# 58    60    1   2            1   10.091     4
# 63    45    1   1            1    8.370     4
# 67    17    1   2            1   10.832     4
# 72    24    0   2            0   10.605     4
# 79    32    0   1            1   10.840     4
# 81    64    1   2            0    7.761     4
# 86    51    0   2            0   13.597     4
# 95    36    1   1            1   11.424     4
# 103   56    1   2            0    8.966     4
# 105   37    1   1            1    8.968     4
# 106   22    1   2            0   11.953     4
# 111   47    0   2            1    6.683     4
# 112   35    1   1            1    9.170     4
# 113   65    0   1            1   13.769     4
# 114   20    0   2            1    9.281     4
# 116   67    1   2            1    9.514     4
# 117   40    0   2            0   10.103     4
# 127   35    1   2            1    7.845     4
# 129   32    0   2            0    7.477     4
# 132   49    1   1            1   13.598     4
# 135   74    1   1            1   11.939     4
# 139   69    0   2            0   10.065     4
# 145   61    1   2            0    9.443     4
# 146   37    0   1            1   12.006     4
# 148   61    0   1            1    7.340     4
# 152   55    1   2            1    7.261     4
# 153   72    0   1            1   14.642     4
# 159   34    0   1            1   12.923     4
# 160   30    0   2            0   10.443     4
# 162   43    1   2            1   12.859     4
# 167   57    0   2            0   14.216     4
# 170   28    0   2            0   12.879     4
# 171   45    1   1            1   10.017     4
# 181   59    0   2            0   13.884     4
# 182   20    0   1            1   11.686     4
# 197   52    1   2            0    9.894     4
# 198   23    1   2            1   14.020     4
# 199   40    0   1            1   11.349     4

# %%
# Drug2 확인 (Drug3과 데이터 개수가 같음)
drug2 = df['Drug'] == 2
drug2_df = df[drug2]
drug2_df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 31    74    1   0            0    9.567     2
# 41    58    0   0            1   14.239     2
# 54    68    0   0            1   10.189     2
# 56    65    1   0            1   11.340     2
# 64    60    0   0            0   13.303     2
# 70    70    1   0            0   13.967     2
# 80    60    1   0            0   13.934     2
# 85    59    1   0            0   13.935     2
# 108   72    1   0            1    9.677     2
# 124   53    0   0            1   12.495     2
# 136   55    0   0            0   10.977     2
# 138   51    1   0            1   11.343     2
# 142   60    1   0            1    8.621     2
# 151   68    1   0            0   11.009     2
# 161   57    0   0            1    9.945     2
# 186   70    1   0            0    9.849     2

# %%
# Drug1 확인 (데이터 수가 많지는 않지만 비교적 단순한 패턴을 가짐)
drug1 = df['Drug'] == 1
drug1_df = df[drug1]
drug1_df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 17    43    1   0            0   13.972     1
# 36    32    1   0            1    9.445     1
# 46    37    0   0            0   13.091     1
# 61    24    1   0            1    9.475     1
# 66    29    1   0            0   12.856     1
# 76    36    0   0            0   11.198     1
# 78    19    0   0            0   13.313     1
# 83    38    0   0            1   11.326     1
# 100   31    1   0            1   11.871     1
# 101   45    0   0            0   12.854     1
# 110   50    1   0            0    7.490     1
# 118   32    0   0            1   10.292     1
# 137   35    0   0            0   12.894     1
# 140   49    1   0            1    6.269     1
# 144   39    1   0            0    9.664     1
# 147   26    0   0            1   12.307     1
# 150   49    1   0            1    8.700     1
# 156   31    1   0            1   11.227     1
# 169   20    0   0            0   11.262     1
# 174   42    1   0            1   12.766     1
# 176   48    1   0            1   10.446     1
# 187   47    1   0            0   10.403     1
# 191   23    1   0            0    8.011     1

# %%
# Drug0 확인 (데이터 수가 가장 많고, 특히 Na_to_K 수치가 타Class 보다 높은 편에 속함)
drug0 = df['Drug'] == 0
drug0_df = df[drug0]
drug0_df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0     23    0   0            0   25.355     0
# 4     61    0   1            0   18.043     0
# 6     49    0   2            0   16.275     0
# 8     60    1   2            0   15.171     0
# 9     43    1   1            1   19.368     0
# ..   ...  ...  ..          ...      ...   ...
# 188   65    1   0            1   34.997     0
# 189   64    1   0            1   20.932     0
# 190   58    1   0            0   18.991     0
# 192   72    1   1            0   16.310     0
# 194   46    0   0            0   34.686     0
#
# [91 rows x 6 columns]

# %% [markdown]
# 결론(요약) :
#
# - 클래스는 DrugY(0), drugA(1), drugB(2), drugC(3), drugX(4)로 Label Encoding 했다.
#
# - 분류 클래스인 Drug의 각 개수는 DrugY(45.5%, 91개), drugX(27%, 54개), drugA(11.5%, 23개), drugB와 drugC는 각 8%(16개)였다.
#
# - drugC(3)를 drugX(4)로 잘못 예측한 1건 외로는 정확하게 예측했다. (Accuracy : 0.98)
#
# - 예측이 잘된 Drug 0, 1, 2는 비교적 특징이 명확한 편이라 학습의 경우의 수가 많지 않았다. 같은 Sex, BP, Cholesterol이라도 Na_to_K 수치가 일정부분 이상에 해당된다거나. 유사한 부분을 특징으로 잡고 분류하므로 그 영향이 있는 듯 하다. 이 데이터의 경우 특징을 잡을 컬럼 수가 많지 않고, 잘못 예측한 Drug3은 데이터가 다른 클래스에 비해 적은데 특징의 경우의 수가 많은 게 영향이 있는 것 같다.
